# %%
# %run functions.py
# BOM
machined, purchased = loadBOM('Data/GF12 BOM Master Tab Copies 1.27.24.xlsx')
#PO
po = loadPO('Data/GF12 All Purchase Orders By Job 1.27.24.xlsx')
po = mapPOtoPurchased(po, purchased)


print('PO')
display(po.head())
print('BOM Machined')
display(machined.head())
print('BOM Purchased')
display(purchased.head())
# Out:
# Refreshed.
# PO
#              Type       Date    Num                      Source Name  \
# 0  Purchase Order 2022-11-11  54540  Quality Bearings and Components
# 1  Purchase Order 2022-11-16  54563             AAP Automation, Inc.
# 2  Purchase Order 2022-11-16  54563             AAP Automation, Inc.
# 3  Purchase Order 2022-11-16  54563             AAP Automation, Inc.
# 4  Purchase Order 2022-11-16  54563             AAP Automation, Inc.
#
#   Part Number  \
# 0     7616DLG
# 1      001283
# 2      001283
# 3      001283
# 4      001526
#
#                                                                                                   Item  \
# 0                                                                7616DLG (INSERT BEARING WITH SHIELDS)
# 1  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
# 2  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
# 3  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
# 4  001526 (BRC Drive package consisting of: R911397897 (HCS01.1E-W0005-A-03-B-ET-EC-EP-L4-NN-FW) an...
#
#                                                                                       Item Description  \
# 0                                                                          INSERT BEARING WITH SHIELDS
# 1  BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) and R91134...
# 2  BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) and R91134...
# 3  BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) and R91134...
# 4  BRC Drive package consisting of: R911397897 (HCS01.1E-W0005-A-03-B-ET-EC-EP-L4-NN-FW) and R91134...
#
#    Cost Price  Qty  Pack Qty  Unit Price  Unit Qty   Override 1 Override 2
# 0       10.00  3.0       1.0       10.00       3.0  Non-Machine    Samples
# 1     1775.07  8.0       1.0     1775.07       8.0          NaN        NaN
# 2     1775.07  2.0       1.0     1775.07       2.0          NaN        NaN
# 3     1775.07  5.0       1.0     1775.07       5.0          NaN        NaN
# 4     1527.39  1.0       1.0     1527.39       1.0          NaN        NaN
# BOM Machined
#    Part Number Rev       Machined                       Description    Cost  \
# 0  GF12.110.01   A  GF12.110.01.A   MODIFIED BRX 90x90 -I- \n3936MM    0.00
# 1  GF12.110.02   A  GF12.110.02.A  MODIFIED BRX 90X90 -I- 3282.92MM    0.00
# 2  GF12.111.01   A  GF12.111.01.A            M8 Leveling Foot Plate   37.50
# 3  GF12.112.01   A  GF12.112.01.A                     Joining Plate   73.00
# 4  GF12.113.01   A  GF12.113.01.A             .300, .600 RAIL PLATE  351.75
#
#    Qty       Vendor    Locations
# 0    2  BRX, NULINE   , 2x110.1,
# 1    2  BRX, NULINE   , 2x110.2,
# 2   26      Big Sky  , 26x111.1,
# 3   10      BIG SKY  , 10x112.1,
# 4    4        BEMOX   , 4x113.1,
# BOM Purchased
#   Part Number  \
# 0      001283
# 1      001526
# 2        8751
# 3      022198
# 4       98635
#
#                                                                                                                            Description  \
# 0  Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) and R911347141 (FWA-INDRV*-MPB-20VRS-D5-1-NNN-NN)
# 1    Drive package consisting of: R911397897(BRC, HCS01.1E-W0005-A-03-B-ET-EC-EP-L4-N),  R911347141 (FWA-INDRV*-MPB-20VRS-D5-1-NNN-NN)
# 2                                                                                              ELESA Wing Nut 8751 CTL.476/40 p-M8x16
# 3                                                                                                    Dienes 022198 MALE/FEMALE ADAPTER
# 4                                                                                                   STOBER BUSHING ADAPTER 9MM TO 11MM
#
#    Pack Qty                 Locations
# 0       1.0  , 13x001.301, 2x002.313,
# 1       1.0              , 2x001.302,
# 2       1.0   , 2x331.310, 2x631.310,
# 3       1.0              , 1x730.302,
# 4       1.0               , 1x820.306

# %%
# print duplicates in po['Part Number'] that have different Override 1 values
print('Duplicates in PO')
dup = po[po.duplicated(subset=['Part Number'], keep=False)].sort_values(by=['Part Number'])
uniqueParts = dup['Part Number'].unique()
display(dup[dup['Part Number'] == uniqueParts[4]])
# Out:
# Duplicates in PO
#                Type       Date    Num        Source Name Part Number  \
# 514  Purchase Order 2023-08-23  55079  Motion Industries  1AM030AFXK
# 963  Purchase Order 2023-09-27  55171  Motion Industries  1AM030AFXK
#
#                                                                                          Item  \
# 514  1AM030AFXK (Flange-Mount Shaft Collar for 30 mm Diameter, Black-Oxide 1117 Carbon Steel)
# 963  1AM030AFXK (Flange-Mount Shaft Collar for 30 mm Diameter, Black-Oxide 1117 Carbon Steel)
#
#                                                                 Item Description  \
# 514  Flange-Mount Shaft Collar for 30 mm Diameter, Black-Oxide 1117 Carbon Steel
# 963  Flange-Mount Shaft Collar for 30 mm Diameter, Black-Oxide 1117 Carbon Steel
#
#      Cost Price   Qty  Pack Qty  Unit Price  Unit Qty      Override 1  \
# 514       65.21  14.0       1.0       65.21      14.0             NaN
# 963       65.21   0.0       1.0       65.21       0.0  Cancelled Item
#
#     Override 2
# 514        NaN
# 963        NaN

# %%
lookupPartNumber(po, '001283')
# Out:
#              Type       Date    Num           Source Name Part Number  \
# 1  Purchase Order 2022-11-16  54563  AAP Automation, Inc.      001283
# 2  Purchase Order 2022-11-16  54563  AAP Automation, Inc.      001283
# 3  Purchase Order 2022-11-16  54563  AAP Automation, Inc.      001283
#
#                                                                                                   Item  \
# 1  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
# 2  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
# 3  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
#
#                                                                                       Item Description  \
# 1  BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) and R91134...
# 2  BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) and R91134...
# 3  BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) and R91134...
#
#    Cost Price  Qty  Pack Qty  Unit Price  Unit Qty Override 1 Override 2
# 1     1775.07  8.0       1.0     1775.07       8.0        NaN        NaN
# 2     1775.07  2.0       1.0     1775.07       2.0        NaN        NaN
# 3     1775.07  5.0       1.0     1775.07       5.0        NaN        NaN

# %%
# %run functions.py 
final = process_parts(po, machined, purchased, verbose=True)
# Out:
# Refreshed.
# Found 712 machined parts and 800 other parts, with 1512 total unique parts.
#
# ['GF12.120.02']
# GF12.120.02
# PO
#                Type       Date    Num            Source Name  \
# 908  Purchase Order 2023-09-19  55158  Professional Plastics
# 914  Purchase Order 2023-09-19  55158  Professional Plastics
#
#     Part Number Machined                                           Item  \
# 908        GF12.120.02.B  GF12.120.02.B (THIN WALL TOP GUARD 4 - REV B)
# 914        GF12.120.02.A      GF12.120.02.A (Thin Wall Top Guard 2-3  )
#
#                   Item Description  Cost Price  Qty  Pack Qty  Unit Price  \
# 908  THIN WALL TOP GUARD 4 - REV B         0.0  1.0       1.0         0.0
# 914        Thin Wall Top Guard 2-3         0.0  0.0       1.0         0.0
#
#      Unit Qty      Override 1 Override 2  Part Number
# 908       1.0             NaN        NaN  GF12.120.02
# 914       0.0  Cancelled Item        NaN  GF12.120.02
# Machined
#     Part Number Rev       Machined            Description      Cost  Qty  \
# 15  GF12.120.02   C  GF12.120.02.C  Thin Wall Top Guard 4  110.1544    1
#
#           Vendor   Locations
# 15  PRO PLASTICS  , 1x120.2,

# %%
final
