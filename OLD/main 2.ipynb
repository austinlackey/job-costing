# %%
# %run functions.py # Import functions

# Load Data
po = loadPO('Data/GF12 All Purchase Orders.xlsx')

# data_dict = loadBOMs('Data/GF12 BOM Master Tab Copies.xlsx')
# assemblies = data_dict.get('assemblies')
# machined = data_dict.get('machined')
# purchased = data_dict.get('purchased')
# extrusion = data_dict.get('extrusion')
purchased = loadBOM_Purchased('Data/GF12 BOM Purchased.csv')

# Map Data
po = mapPOtoPurchased(po, purchased)

print("PO")
display(po.head())


# print("Assemblies")
# display(assemblies.head())
# print("Machined")
# display(machined.head())
print("Purchased")
display(purchased.head())
# print("Extrusion")
# display(extrusion.head())
# Out:
# PO
#              Type       Date    Num                     Source Name  \
# 0  Purchase Order 2023-02-24  54758  American Feeding Systems, Inc.
# 1  Purchase Order 2023-02-24  54758  American Feeding Systems, Inc.
# 2  Purchase Order 2023-11-14  55295  American Feeding Systems, Inc.
# 3  Purchase Order 2023-08-18  55060                Fiero Automation
# 4  Purchase Order 2023-10-06  55195                 Elesa USA Corp.
#
#      Part Number  \
# 0  2301-136Rev.3
# 1  2301-137Rev.3
# 2           Misc
# 3          14012
# 4      260411-C1
#
#                                                                                                   Item  \
# 0                                     2301-136Rev.3 (Bowl Feeder Assembly per AFS Quote 2301-136Rev.3)
# 1                                     2301-137Rev.3 (Bowl Feeder Assembly per AFS Quote 2301-137Rev.3)
# 2                                                                                     Misc (Misc Item)
# ...

# %%
lookupPartNumber(po, '001283')
# Out:
#               Type       Date    Num           Source Name Part Number  \
# 63  Purchase Order 2022-11-16  54563  AAP Automation, Inc.      001283
# 64  Purchase Order 2022-11-16  54563  AAP Automation, Inc.      001283
# 65  Purchase Order 2022-11-16  54563  AAP Automation, Inc.      001283
#
#                                                                                                    Item  \
# 63  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
# 64  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
# 65  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
#
#                                                                                        Item Description  \
# 63  BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) and R91134...
# ...

# %%
# %run functions.py
# process_purchased_part('614NHH', purchased, po, verbose=True)
# process_purchased_part('94708A213', purchased, po, verbose=True)
# process_purchased_part('R911390100', purchased, po, verbose=True)
# process_purchased_part('KQ2L08-U02A', purchased, po, verbose=True)
# process_purchased_part('HCA-0.5X24.5-277-1850W-O11203', purchased, po, verbose=True)
process_purchased_part('001283', purchased, po, verbose=True)
# Out:
#   Location   Qty
# 0  001.301  13.0
# 1  002.313   2.0
# Purchase Order
#              Type       Date    Num           Source Name Part Number  \
# 0  Purchase Order 2022-11-16  54563  AAP Automation, Inc.      001283
# 1  Purchase Order 2022-11-16  54563  AAP Automation, Inc.      001283
# 2  Purchase Order 2022-11-16  54563  AAP Automation, Inc.      001283
#
#                                                                                                   Item  \
# 0  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
# 1  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
# 2  001283 (BRC Drive package consisting of: R911331611 (HCS01.1E-W0028-A-03-B-ET-EC-NN-L4-NN-FW) an...
#
#                                                                                       Item Description  \
# ...

# %%
# display po where Part Number contains GF12
display(po[po['Part Number'].str.contains('GF12.141')])
# Out:
#                Type       Date    Num             Source Name    Part Number  \
# 392  Purchase Order 2023-08-23  55091  Big Sky Energy Eq. Inc  GF12.141.01.B
#
#                                                                                  Item  \
# 392  GF12.141.01.B (Slit Knife Handwheel Shaft REV B, Material by Nuline, Labor only)
#
#                                                      Item Description  \
# 392  Slit Knife Handwheel Shaft REV B, Material by Nuline, Labor only
#
#      Cost Price  Qty  Pack Qty  Unit Price  Unit Qty Override 1 Override 2
# 392       98.75  1.0       1.0       98.75       1.0        NaN        NaN

# %%
display(machined.head(40))
part = 'GF12.140.06'
print("PO")
display(lookupPartNumber(po, part, verbatim=False))
print("Machined")
display(lookupPartNumber(machined, part, verbatim=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 display(machined.head(40))
#       2 part = 'GF12.140.06'
#       3 print("PO")
#
# NameError: name 'machined' is not defined

# %%
lookupPartNumber(po, 'ND8-24-', verbatim=False)
# Out:
#                Type       Date    Num       Source Name  \
# 113  Purchase Order 2023-05-31  54911  Fiero Automation
#
#                  Part Number  \
# 113  ND8-24-20-B-102-LT-IP65
#
#                                                                         Item  \
# 113  ND8-24-20-B-102-LT-IP65 (NOOK Linear Acme Screw Actuator, 102mm Travel)
#
#                                   Item Description  Cost Price  Qty  Pack Qty  \
# 113  NOOK Linear Acme Screw Actuator, 102mm Travel      946.12  2.0       1.0
#
#      Unit Price  Unit Qty Override 1 Override 2
# 113      946.12       2.0     Unused        NaN

# %%
# %run functions.py
process_parts(purchased, po, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 get_ipython().run_line_magic('run', 'functions.py')
# ----> 2 process_parts(purchased, po, verbose=True)
#
# NameError: name 'process_parts' is not defined
